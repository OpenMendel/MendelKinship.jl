# %%
using MendelKinship, CSV, DataFrames

#output for openmendel
open_mendel_output = Kinship("control10c.txt")
# open_mendel_output = Kinship("control23a.txt")


# output of Mendel with ran with settings: 
# MODEL = 1
# MIN_MAF = 0.01
# KINSHIP_SOURCE = SNPs_with_everyone
# SNP_SAMPLING_INCREMENT = 1
mendel_output = readdlm("Summary10c.out", header = true)
# mendel_output = readdlm("Summary23a.out", header = true)


# convert everything to dataframe, easier to work with
mendel_output_df = convert(DataFrame, mendel_output[1])
rename!(mendel_output_df, f => t for (f, t) = 
    zip([:x1, :x2, :x3, :x4, :x5, :x6], 
        [:Pedigree1, :Person1, :Pedigree2, 
        :Person2, :expected_kinship, :empiric_kinship]))
# Out:
#
#
#      Welcome to OpenMendel's
#      Kinship analysis option
#         version 0.1.0
#
#
# Reading the data.
#
# The current working directory is "/Users/biona001/.julia/v0.6/MendelKinship/test".
#
# Keywords modified by the user:
#
#   compare_kinships = true
#   control_file = control10c.txt
#   field_separator = ,
#   maf_threshold = 0.01
#   pedigree_file = Ped10c.in
#   snpdata_file = SNP_data10c.bed
#   snpdefinition_file = SNP_def10c_converted.txt
# WARNING: readtable is deprecated, use CSV.read from the CSV package instead
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:70
#  [2] #readtable#233(::Bool, ::Char, ::Array{Char,1}, ::Char, ::Array{String,1}, ::Array{String,1}, ::Array{String,1}, ::Bool, ::Int64, ::Array{Symbol,1}, ::Array{Any,1}, ::Bool, ::Char, ::Bool, ::Int64, ::Array{Int64,1}, ::Bool, ::Symbol, ::Bool, ::Bool, ::DataFrames.#readtable, ::SubString{String}) at /Users/biona001/.julia/v0.6/DataFrames/src/deprecated.jl:1050
#  [3] (::DataFrames.#kw##readtable)(::Array{Any,1}, ::DataFrames.#readtable, ::SubString{String}) at ./<missing>:0
#  [4] read_external_data_files(::Dict{AbstractString,Any}) at /Users/biona001/.julia/v0.6/MendelBase/src/read_data.jl:70
#  [5] #Kinship#1(::Array{Any,1}, ::Function, ::String) at /Users/biona001/.julia/v0.6/MendelKinship/src/MendelKinship.jl:75
#  [6] Kinship(::String) at /Users/biona001/.julia/v0.6/MendelKinship/src/MendelKinship.jl:27
#  [7] include_string(::String, ::String) at ./loading.jl:515
#  [8] include_string(::Module, ::String, ::String) at /Users/biona001/.julia/v0.6/Compat/src/Compat.jl:71
#  [9] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /Users/biona001/.julia/v0.6/IJulia/src/execute_request.jl:158
#  [10] (::Compat.#inner#17{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at /Users/biona001/.julia/v0.6/Compat/src/Compat.jl:385
#  [11] eventloop(::ZMQ.Socket) at /Users/biona001/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [12] (::IJulia.##14#17)() at ./task.jl:335
# while loading In[1], in expression starting on line 4
# WARNING: Duplicate variable names are deprecated: pass makeunique=true to add a suffix automatically.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:70
#  [2] #make_unique#3(::Bool, ::Function, ::Array{Symbol,1}) at /Users/biona001/.julia/v0.6/DataFrames/src/other/utils.jl:63
#  [3] (::DataFrames.#kw##make_unique)(::Array{Any,1}, ::DataFrames.#make_unique, ::Array{Symbol,1}) at ./<missing>:0
#  [4] #Index#6 at /Users/biona001/.julia/v0.6/DataFrames/src/other/index.jl:12 [inlined]
#  [5] (::Core.#kw#Type)(::Array{Any,1}, ::Type{DataFrames.Index}, ::Array{Symbol,1}) at ./<missing>:0
#  [6] #DataFrame#57(::Bool, ::Type{T} where T, ::Array{Any,1}, ::Array{Symbol,1}) at /Users/biona001/.julia/v0.6/DataFrames/src/dataframe/dataframe.jl:138
#  [7] builddf(::Int64, ::Int64, ::Int64, ::Int64, ::DataFrames.ParsedCSV, ::DataFrames.ParseOptions{String,String}) at /Users/biona001/.julia/v0.6/DataFrames/src/deprecated.jl:772
#  [8] readtable!(::DataFrames.ParsedCSV, ::IOStream, ::Int64, ::DataFrames.ParseOptions{String,String}) at /Users/biona001/.julia/v0.6/DataFrames/src/deprecated.jl:912
#  [9] #readtable#232(::Bool, ::Char, ::Array{Char,1}, ::Char, ::Array{String,1}, ::Array{String,1}, ::Array{String,1}, ::Bool, ::Int64, ::Array{Symbol,1}, ::Array{Any,1}, ::Bool, ::Char, ::Bool, ::Int64, ::Array{Int64,1}, ::Bool, ::Symbol, ::Bool, ::Bool, ::DataFrames.#readtable, ::IOStream, ::Int64) at /Users/biona001/.julia/v0.6/DataFrames/src/deprecated.jl:971
#  [10] (::DataFrames.#kw##readtable)(::Array{Any,1}, ::DataFrames.#readtable, ::IOStream, ::Int64) at ./<missing>:0
#  [11] open(::DataFrames.#_r#234{Bool,Char,Array{Char,1},Char,Array{String,1},Array{String,1},Array{String,1},Bool,Int64,Array{Symbol,1},Array{Any,1},Bool,Char,Bool,Int64,Array{Int64,1},Bool,Symbol,Bool,Bool}, ::SubString{String}, ::String) at ./iostream.jl:152
#  [12] #readtable#233(::Bool, ::Char, ::Array{Char,1}, ::Char, ::Array{String,1}, ::Array{String,1}, ::Array{String,1}, ::Bool, ::Int64, ::Array{Symbol,1}, ::Array{Any,1}, ::Bool, ::Char, ::Bool, ::Int64, ::Array{Int64,1}, ::Bool, ::Symbol, ::Bool, ::Bool, ::DataFrames.#readtable, ::SubString{String}) at /Users/biona001/.julia/v0.6/DataFrames/src/deprecated.jl:1090
#  [13] (::DataFrames.#kw##readtable)(::Array{Any,1}, ::DataFrames.#readtable, ::SubString{String}) at ./<missing>:0
#  [14] read_external_data_files(::Dict{AbstractString,Any}) at /Users/biona001/.julia/v0.6/MendelBase/src/read_data.jl:70
#  [15] #Kinship#1(::Array{Any,1}, ::Function, ::String) at /Users/biona001/.julia/v0.6/MendelKinship/src/MendelKinship.jl:75
#  [16] Kinship(::String) at /Users/biona001/.julia/v0.6/MendelKinship/src/MendelKinship.jl:27
#  [17] include_string(::String, ::String) at ./loading.jl:515
#  [18] include_string(::Module, ::String, ::String) at /Users/biona001/.julia/v0.6/Compat/src/Compat.jl:71
#  [19] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /Users/biona001/.julia/v0.6/IJulia/src/execute_request.jl:158
#  [20] (::Compat.#inner#17{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at /Users/biona001/.julia/v0.6/Compat/src/Compat.jl:385
#  [21] eventloop(::ZMQ.Socket) at /Users/biona001/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [22] (::IJulia.##14#17)() at ./task.jl:335
# while loading In[1], in expression starting on line 4
# WARNING: readtable is deprecated, use CSV.read from the CSV package instead
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:70
#  [2] #readtable#233(::Bool, ::Char, ::Array{Char,1}, ::Char, ::Array{String,1}, ::Array{String,1}, ::Array{String,1}, ::Bool, ::Int64, ::Array{Symbol,1}, ::Array{Any,1}, ::Bool, ::Char, ::Bool, ::Int64, ::Array{Int64,1}, ::Bool, ::Symbol, ::Bool, ::Bool, ::DataFrames.#readtable, ::SubString{String}) at /Users/biona001/.julia/v0.6/DataFrames/src/deprecated.jl:1050
#  [3] (::DataFrames.#kw##readtable)(::Array{Any,1}, ::DataFrames.#readtable, ::SubString{String}) at ./<missing>:0
#  [4] read_external_data_files(::Dict{AbstractString,Any}) at /Users/biona001/.julia/v0.6/MendelBase/src/read_data.jl:125
#  [5] #Kinship#1(::Array{Any,1}, ::Function, ::String) at /Users/biona001/.julia/v0.6/MendelKinship/src/MendelKinship.jl:75
#  [6] Kinship(::String) at /Users/biona001/.julia/v0.6/MendelKinship/src/MendelKinship.jl:27
#  [7] include_string(::String, ::String) at ./loading.jl:515
#  [8] include_string(::Module, ::String, ::String) at /Users/biona001/.julia/v0.6/Compat/src/Compat.jl:71
#  [9] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /Users/biona001/.julia/v0.6/IJulia/src/execute_request.jl:158
#  [10] (::Compat.#inner#17{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at /Users/biona001/.julia/v0.6/Compat/src/Compat.jl:385
#  [11] eventloop(::ZMQ.Socket) at /Users/biona001/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [12] (::IJulia.##14#17)() at ./task.jl:335
# while loading In[1], in expression starting on line 4
# INFO: v1.0 BED file detected
#
# Analyzing the data.
# 22578×6 DataFrames.DataFrame. Omitted printing of 1 columns
# │ Row   │ Pedigree1 │ Person1 │ Pedigree2 │ Person2 │ expected_kinship │
# ├───────┼───────────┼─────────┼───────────┼─────────┼──────────────────┤
# │ 1     │ 1.0       │ 16.0    │ 1.0       │ 16.0    │ 0.5              │
# │ 2     │ 1.0       │ 8228.0  │ 1.0       │ 16.0    │ 0.0              │
# │ 3     │ 1.0       │ 8228.0  │ 1.0       │ 8228.0  │ 0.5              │
# │ 4     │ 1.0       │ 17008.0 │ 1.0       │ 16.0    │ 0.0              │
# │ 5     │ 1.0       │ 17008.0 │ 1.0       │ 8228.0  │ 0.0              │
# │ 6     │ 1.0       │ 17008.0 │ 1.0       │ 17008.0 │ 0.5              │
# │ 7     │ 1.0       │ 9218.0  │ 1.0       │ 16.0    │ 0.25             │
# │ 8     │ 1.0       │ 9218.0  │ 1.0       │ 8228.0  │ 0.0              │
# │ 9     │ 1.0       │ 9218.0  │ 1.0       │ 17008.0 │ 0.25             │
# │ 10    │ 1.0       │ 9218.0  │ 1.0       │ 9218.0  │ 0.5              │
# │ 11    │ 1.0       │ 3226.0  │ 1.0       │ 16.0    │ 0.125            │
# ⋮
# │ 22567 │ 10045.0   │ 789.0   │ 31.0      │ 24385.0 │ 0.0              │
# │ 22568 │ 10045.0   │ 789.0   │ 31.0      │ 21403.0 │ 0.0              │
# │ 22569 │ 10045.0   │ 789.0   │ 31.0      │ 1365.0  │ 0.0              │
# │ 22570 │ 10045.0   │ 789.0   │ 31.0      │ 19392.0 │ 0.0              │
# │ 22571 │ 10045.0   │ 789.0   │ 10006.0   │ 66.0    │ 0.0              │
# │ 22572 │ 10045.0   │ 789.0   │ 10008.0   │ 92.0    │ 0.0              │
# │ 22573 │ 10045.0   │ 789.0   │ 10014.0   │ 186.0   │ 0.0              │
# │ 22574 │ 10045.0   │ 789.0   │ 10027.0   │ 374.0   │ 0.0              │
# │ 22575 │ 10045.0   │ 789.0   │ 10029.0   │ 434.0   │ 0.0              │
# │ 22576 │ 10045.0   │ 789.0   │ 10033.0   │ 333.0   │ 0.0              │
# │ 22577 │ 10045.0   │ 789.0   │ 10040.0   │ 234.0   │ 0.0              │
# │ 22578 │ 10045.0   │ 789.0   │ 10045.0   │ 789.0   │ 0.5              │

# %%
open_mendel_output
# Out:
# 44944×6 DataFrames.DataFrame. Omitted printing of 1 columns
# │ Row   │ Pedigree1 │ Pedigree2 │ Person1 │ Person2 │ theoretical_kinship │
# ├───────┼───────────┼───────────┼─────────┼─────────┼─────────────────────┤
# │ 1     │ 17        │ 17        │ 1649    │ 6637    │ 0.0                 │
# │ 2     │ 17        │ 17        │ 6637    │ 1649    │ 0.0                 │
# │ 3     │ 17        │ 17        │ 20334   │ 22601   │ 0.0                 │
# │ 4     │ 17        │ 17        │ 22601   │ 20334   │ 0.0                 │
# │ 5     │ 24        │ 24        │ 13575   │ 19621   │ 0.0                 │
# │ 6     │ 24        │ 24        │ 19621   │ 13575   │ 0.0                 │
# │ 7     │ 25        │ 25        │ 11822   │ 22041   │ 0.0                 │
# │ 8     │ 25        │ 25        │ 22041   │ 11822   │ 0.0                 │
# │ 9     │ 25        │ 25        │ 24192   │ 22041   │ 0.0                 │
# │ 10    │ 25        │ 25        │ 22041   │ 24192   │ 0.0                 │
# │ 11    │ 25        │ 25        │ 5299    │ 22041   │ 0.0                 │
# ⋮
# │ 44933 │ 17        │ 14        │ 11879   │ 4078    │ 0.0                 │
# │ 44934 │ 14        │ 17        │ 4078    │ 11879   │ 0.0                 │
# │ 44935 │ 10        │ 8         │ 480     │ 7395    │ 0.0                 │
# │ 44936 │ 8         │ 10        │ 7395    │ 480     │ 0.0                 │
# │ 44937 │ 10006     │ 27        │ 66      │ 17917   │ 0.0                 │
# │ 44938 │ 27        │ 10006     │ 17917   │ 66      │ 0.0                 │
# │ 44939 │ 31        │ 2         │ 27017   │ 2294    │ 0.0                 │
# │ 44940 │ 2         │ 31        │ 2294    │ 27017   │ 0.0                 │
# │ 44941 │ 31        │ 2         │ 5777    │ 29      │ 0.0                 │
# │ 44942 │ 2         │ 31        │ 29      │ 5777    │ 0.0                 │
# │ 44943 │ 29        │ 19        │ 18775   │ 22375   │ 0.0                 │
# │ 44944 │ 19        │ 29        │ 22375   │ 18775   │ 0.0                 │

# %% [markdown]
# Since SnpArrays package expects BED file. We create a symbolic link to the SNP_data10c.bin file, which same as BED file.

# %%
;ln -s ./SNP_data10c.bin ./SNP_data10c.bed
# Out:
# ln: ./SNP_data10c.bed: File exists

# %%
using SnpArrays

#make the GRM matrix, to compare with OpenMendel's empiric output later
s = SnpArray("SNP_data10c"; people=212, snps=253141)
GRM = grm(s, method=:GRM, maf_threshold=0.01)
# Out:
# INFO: v1.0 BED file detected
# 212×212 Array{Float64,2}:
#   0.488859      0.00422798    0.00978752   …   0.0187809     0.000152741
#   0.00422798    0.515141     -0.0190676       -0.0220944    -0.0162381
#   0.00978752   -0.0190676     0.489156        -0.0143552    -0.00392193
#   0.241927     -0.00231651    0.266756         0.00264766   -0.00334162
#   0.124909      0.265109      0.12103         -0.0118053    -0.00641433
#  -0.0121766    -0.000271784  -0.00316506   …  -0.000629837   0.0103776
#  -0.011988      0.00845464   -0.00950518      -0.0105435     0.000340285
#  -0.0134368    -0.00713175   -0.0101011       -0.0115942    -0.00288935
#  -0.0111854     0.00423488   -0.0117065       -0.0244977    -0.00698659
#  -0.0124607    -0.00575043   -0.0124951       -0.00573017   -0.0103429
#  -0.0128464     0.010258      0.00110475   …  -0.00424998    0.0124296
#  -0.0121471     0.00305141   -0.00754556      -0.0104162     0.00554306
#  -0.0234305    -0.00241126   -0.010413         0.000129339   0.0166282
#   ⋮                                        ⋱   ⋮
#   0.000390703  -0.00829937   -0.0134343    …   0.00203895   -0.0193534
#   0.00338078    0.00116913   -0.0137822       -0.000709205   0.00437081
#  -0.0131106    -0.0246602    -0.00377814      -0.0167851    -0.0115794
#  -0.016104     -0.014253     -0.0132132       -0.023015      0.000196427
#  -0.00215359    0.0120041    -0.002889        -0.00294264   -0.00290955
#   0.00353341   -0.00200184   -0.00346206   …   0.0240445     0.0224584
#  -0.0132247    -0.00736188    0.000399022     -0.0115962     0.00801023
#   0.0136135     0.014919      0.0146852        0.00611176    0.00984425
#  -0.00763248   -0.00216137    0.0227918        0.00711085   -0.0159608
#   0.000154845  -0.0142528     0.0109832        0.00490078    0.00924588
#   0.0187809    -0.0220944    -0.0143552    …   0.556933      0.0380902
#   0.000152741  -0.0162381    -0.00392193       0.0380902     0.502935

# %% [markdown]
# ### Use Hua's code to create vectorized GRM matrix Φ_snparray matched up with the rest of the data

# %%
ped = readcsv("Ped10c.in")
famid, perid = Int.(ped[2:end, 1]), Int.(ped[2:end, 2])
mendel_famid_1 = Int.(mendel_output_df[:Pedigree1])
mendel_perid_1 = Int.(mendel_output_df[:Person1])
mendel_famid_2 = Int.(mendel_output_df[:Pedigree2])
mendel_perid_2 = Int.(mendel_output_df[:Person2])
Φ_theoretical = mendel_output_df[:expected_kinship]
Φ_empirical = mendel_output_df[:empiric_kinship]

function index_in_ped(fid, pid, fid_list, pid_list)
    for i in 1:length(fid_list)
        (fid == fid_list[i] && pid == pid_list[i]) && return i
    end
    return 0
end

Φ_snparray = similar(Φ_empirical)
for iter = 1:length(Φ_empirical)
    i = index_in_ped(mendel_famid_1[iter], mendel_perid_1[iter], famid, perid)
    j = index_in_ped(mendel_famid_2[iter], mendel_perid_2[iter], famid, perid)
    Φ_snparray[iter] = GRM[i, j]
end

# %% [markdown]
# ### Problem: sometimes the expected and empiric coefficient is very off (which happens a lot in pedigree 17)

# %%
#extract rows with Pedigree1 == "17"
y = open_mendel_output[open_mendel_output[:, 1] .== "17", :]

#extract rows with Pedigree2 == "17"
y = y[y[:, 2] .== "17", :]

#filter by person
# y = x[x[:, 3] .== "3916", :]
# y = y[y[:, 4] .== "29", :]


#sort by Person1
sort!(y, cols = (:Person1))
# Out:
# 529×6 DataFrames.DataFrame. Omitted printing of 1 columns
# │ Row │ Pedigree1 │ Pedigree2 │ Person1 │ Person2 │ theoretical_kinship │
# ├─────┼───────────┼───────────┼─────────┼─────────┼─────────────────────┤
# │ 1   │ 17        │ 17        │ 10418   │ 1649    │ 0.0625              │
# │ 2   │ 17        │ 17        │ 10418   │ 11879   │ 0.25                │
# │ 3   │ 17        │ 17        │ 10418   │ 6637    │ 0.125               │
# │ 4   │ 17        │ 17        │ 10418   │ 7098    │ 0.25                │
# │ 5   │ 17        │ 17        │ 10418   │ 309     │ 0.125               │
# │ 6   │ 17        │ 17        │ 10418   │ 6932    │ 0.0625              │
# │ 7   │ 17        │ 17        │ 10418   │ 16612   │ 0.25                │
# │ 8   │ 17        │ 17        │ 10418   │ 18645   │ 0.0625              │
# │ 9   │ 17        │ 17        │ 10418   │ 10418   │ 0.5                 │
# │ 10  │ 17        │ 17        │ 10418   │ 20334   │ 0.03125             │
# │ 11  │ 17        │ 17        │ 10418   │ 22301   │ 0.0625              │
# ⋮
# │ 518 │ 17        │ 17        │ 908     │ 309     │ 0.125               │
# │ 519 │ 17        │ 17        │ 908     │ 20334   │ 0.03125             │
# │ 520 │ 17        │ 17        │ 908     │ 19113   │ 0.125               │
# │ 521 │ 17        │ 17        │ 908     │ 19235   │ 0.0625              │
# │ 522 │ 17        │ 17        │ 908     │ 22601   │ 0.0                 │
# │ 523 │ 17        │ 17        │ 908     │ 24818   │ 0.0                 │
# │ 524 │ 17        │ 17        │ 908     │ 11361   │ 0.0625              │
# │ 525 │ 17        │ 17        │ 908     │ 26857   │ 0.0                 │
# │ 526 │ 17        │ 17        │ 908     │ 10418   │ 0.25                │
# │ 527 │ 17        │ 17        │ 908     │ 26856   │ 0.0                 │
# │ 528 │ 17        │ 17        │ 908     │ 19275   │ 0.0                 │
# │ 529 │ 17        │ 17        │ 908     │ 908     │ 0.5                 │

# %% [markdown]
# ### Compare mendel, open mendel, and GRM matrix from SnpArrays by constructing convenient dataframe

# %%
compare = DataFrame(
    Person1 = String[], 
    Person2 = String[], 
    Pedigree1 = String[],
    Pedigree2 = String[],
    Mendel_empiric= Float64[], 
    OpenMendel_empiric=Float64[],
    Φ_SnpArray=Float64[],
    Mendel_theoretical=Float64[],
    OpenMendel_theoretical=Float64[])

m = size(mendel_output_df, 1)
for i in 1:m
    cur_row = mendel_output_df[i, :]
    if cur_row[6][1] == "--"
        continue
    end
    
    person1 = string(Int64(cur_row[2][1]))
    person2 = string(Int64(cur_row[4][1]))
    person1_ped = string(Int64(cur_row[1][1]))
    person2_ped = string(Int64(cur_row[3][1]))


    y = copy(open_mendel_output)
    
    #find rows with Person1 = person1
    y = y[y[:, 3] .== person1, :]

    #find rows with Person2 = person2
    y = y[y[:, 4] .== person2, :]

    push!(compare, [person1, person2, person1_ped, person2_ped, 
        cur_row[6][1], y[6][1], Φ_snparray[i], cur_row[5][1], y[5][1]])
end

# %%
compare
# Out:
# 22578×9 DataFrames.DataFrame. Omitted printing of 4 columns
# │ Row   │ Person1 │ Person2 │ Pedigree1 │ Pedigree2 │ Mendel_empiric │
# ├───────┼─────────┼─────────┼───────────┼───────────┼────────────────┤
# │ 1     │ 16      │ 16      │ 1         │ 1         │ 0.5            │
# │ 2     │ 8228    │ 16      │ 1         │ 1         │ 0.00809        │
# │ 3     │ 8228    │ 8228    │ 1         │ 1         │ 0.5            │
# │ 4     │ 17008   │ 16      │ 1         │ 1         │ 0.01643        │
# │ 5     │ 17008   │ 8228    │ 1         │ 1         │ 0.0            │
# │ 6     │ 17008   │ 17008   │ 1         │ 1         │ 0.5            │
# │ 7     │ 9218    │ 16      │ 1         │ 1         │ 0.25363        │
# │ 8     │ 9218    │ 8228    │ 1         │ 1         │ 0.0            │
# │ 9     │ 9218    │ 17008   │ 1         │ 1         │ 0.28254        │
# │ 10    │ 9218    │ 9218    │ 1         │ 1         │ 0.52612        │
# │ 11    │ 3226    │ 16      │ 1         │ 1         │ 0.1261         │
# ⋮
# │ 22567 │ 789     │ 24385   │ 10045     │ 31        │ 0.0            │
# │ 22568 │ 789     │ 21403   │ 10045     │ 31        │ 0.01081        │
# │ 22569 │ 789     │ 1365    │ 10045     │ 31        │ 0.0            │
# │ 22570 │ 789     │ 19392   │ 10045     │ 31        │ 0.01501        │
# │ 22571 │ 789     │ 66      │ 10045     │ 10006     │ 0.0            │
# │ 22572 │ 789     │ 92      │ 10045     │ 10008     │ 0.02611        │
# │ 22573 │ 789     │ 186     │ 10045     │ 10014     │ 0.00375        │
# │ 22574 │ 789     │ 374     │ 10045     │ 10027     │ 0.00948        │
# │ 22575 │ 789     │ 434     │ 10045     │ 10029     │ 0.0            │
# │ 22576 │ 789     │ 333     │ 10045     │ 10033     │ 0.01501        │
# │ 22577 │ 789     │ 234     │ 10045     │ 10040     │ 0.04971        │
# │ 22578 │ 789     │ 789     │ 10045     │ 10045     │ 0.5            │

# %% [markdown]
# ### See if Mendel and Open Mendel agree in theoretical kinship coeff (the sum should be 0)

# %%
theoretical_error = abs.(compare[:, 8] - compare[:, 9])
sum(theoretical_error)
# Out:
# 0.00018249999999999256

# %%
for i in 1:size(compare, 1)
    if compare[i, 8] != compare[i, 9]
        println(compare[i, 1:2], compare[i, 8:9])
    end
end
# Out:
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 12608   │ 16785   │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.01562            │ 0.015625               │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 13725   │ 16139   │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.01562            │ 0.015625               │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 13725   │ 9277    │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.01562            │ 0.015625               │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 13725   │ 19358   │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.01562            │ 0.015625               │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 13725   │ 10439   │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.01562            │ 0.015625               │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 13725   │ 4512    │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.01562            │ 0.015625               │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 13725   │ 24905   │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.01562            │ 0.015625               │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 13725   │ 16785   │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.00781            │ 0.0078125              │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 13725   │ 26007   │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.01562            │ 0.015625               │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 13725   │ 18037   │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.01562            │ 0.015625               │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 13725   │ 15802   │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.01562            │ 0.015625               │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 13725   │ 152     │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.01562            │ 0.015625               │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 13725   │ 63      │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.01562            │ 0.015625               │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 24385   │ 16139   │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.01562            │ 0.015625               │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 24385   │ 9277    │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.01562            │ 0.015625               │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 24385   │ 19358   │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.01562            │ 0.015625               │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 24385   │ 10439   │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.01562            │ 0.015625               │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 24385   │ 4512    │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.01562            │ 0.015625               │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 24385   │ 24905   │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.01562            │ 0.015625               │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 24385   │ 16785   │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.00781            │ 0.0078125              │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 24385   │ 26007   │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.01562            │ 0.015625               │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 24385   │ 18037   │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.01562            │ 0.015625               │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 24385   │ 15802   │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.01562            │ 0.015625               │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 24385   │ 152     │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.01562            │ 0.015625               │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 24385   │ 63      │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.01562            │ 0.015625               │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 21403   │ 16785   │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.01562            │ 0.015625               │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 1365    │ 16139   │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.01562            │ 0.015625               │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 1365    │ 9277    │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.01562            │ 0.015625               │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 1365    │ 19358   │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.01562            │ 0.015625               │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 1365    │ 10439   │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.01562            │ 0.015625               │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 1365    │ 4512    │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.01562            │ 0.015625               │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 1365    │ 24905   │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.01562            │ 0.015625               │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 1365    │ 16785   │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.00781            │ 0.0078125              │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 1365    │ 26007   │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.01562            │ 0.015625               │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 1365    │ 18037   │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.01562            │ 0.015625               │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 1365    │ 15802   │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.01562            │ 0.015625               │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 1365    │ 152     │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.01562            │ 0.015625               │
# 1×2 DataFrames.DataFrame
# │ Row │ Person1 │ Person2 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 1365    │ 63      │1×2 DataFrames.DataFrame
# │ Row │ Mendel_theoretical │ OpenMendel_theoretical │
# ├─────┼────────────────────┼────────────────────────┤
# │ 1   │ 0.01562            │ 0.015625               │

# %% [markdown]
# ### See if Open Mendel's empiric coefficient is the same as the GRM matrix (sum should be 0)

# %%
GRM_openmendel_diff = abs.(compare[:, 6] - compare[:, 7])
sum(GRM_openmendel_diff)
# Out:
# 263.0448507250909

# %% [markdown]
# ### Is empiric in Open Mendel different than Mendel? (should be centered on 0, due to different ways of calculating GRM)

# %%
using Plots

histogram(compare[:, 5] - compare[:, 6])

# %% [markdown]
# ### Is GRM and Mendel empiric different? (roughly the same as Hua's plot)

# %%
histogram(compare[:, 5] - compare[:, 7])

# %% [markdown]
# ### Is GRM matrix different than open mendel empiric? (there shouldn't be)

# %%
histogram(compare[:, 6] - compare[:, 7])

# %%
# find large deviations
huge_deviations = DataFrame(
    Person1 = String[], 
    Person2 = String[], 
    Pedigree1 = String[],
    Pedigree2 = String[],
    Mendel_empiric= Float64[], 
    OpenMendel_empiric=Float64[],
    Φ_SnpArray=Float64[],
    theoretical=Float64[])

m = size(compare, 1)

for i in 1:m
    cur_row = compare[i, :]
    cur_row = [cur_row[1][1], cur_row[2][1], 
               cur_row[3][1], cur_row[4][1],
               cur_row[5][1], cur_row[6][1],
               cur_row[7][1], cur_row[8][1]]
    
    if abs(cur_row[8] - cur_row[6]) >= 0.05
        push!(huge_deviations, cur_row)
    end
end

# %%
huge_deviations #difference >= 0.05
# Out:
# 627×8 DataFrames.DataFrame. Omitted printing of 3 columns
# │ Row │ Person1 │ Person2 │ Pedigree1 │ Pedigree2 │ Mendel_empiric │
# ├─────┼─────────┼─────────┼───────────┼───────────┼────────────────┤
# │ 1   │ 6790    │ 29      │ 2         │ 2         │ 0.2548         │
# │ 2   │ 6790    │ 2294    │ 2         │ 2         │ 0.24644        │
# │ 3   │ 6790    │ 3416    │ 2         │ 2         │ 0.0            │
# │ 4   │ 14695   │ 6790    │ 2         │ 2         │ 0.26698        │
# │ 5   │ 17893   │ 6790    │ 2         │ 2         │ 0.25369        │
# │ 6   │ 6952    │ 29      │ 2         │ 2         │ 0.1114         │
# │ 7   │ 6952    │ 2294    │ 2         │ 2         │ 0.14461        │
# │ 8   │ 6952    │ 3416    │ 2         │ 2         │ 0.25462        │
# │ 9   │ 6952    │ 3916    │ 2         │ 2         │ 0.10791        │
# │ 10  │ 6952    │ 14695   │ 2         │ 2         │ 0.10753        │
# │ 11  │ 39      │ 39      │ 3         │ 3         │ 0.5            │
# ⋮
# │ 616 │ 19392   │ 4512    │ 31        │ 31        │ 0.0            │
# │ 617 │ 19392   │ 24905   │ 31        │ 31        │ 0.0            │
# │ 618 │ 19392   │ 26007   │ 31        │ 31        │ 0.00184        │
# │ 619 │ 19392   │ 14705   │ 31        │ 31        │ 0.0            │
# │ 620 │ 19392   │ 15802   │ 31        │ 31        │ 0.0            │
# │ 621 │ 19392   │ 15884   │ 31        │ 31        │ 0.0            │
# │ 622 │ 19392   │ 152     │ 31        │ 31        │ 0.0            │
# │ 623 │ 19392   │ 63      │ 31        │ 31        │ 0.0            │
# │ 624 │ 19392   │ 10472   │ 31        │ 31        │ 0.0            │
# │ 625 │ 19392   │ 12608   │ 31        │ 31        │ 0.0            │
# │ 626 │ 19392   │ 21403   │ 31        │ 31        │ 0.0            │
# │ 627 │ 234     │ 234     │ 10040     │ 10040     │ 0.594          │

# %%
println(size(compare))
println(size(huge_deviations))
huge_deviations
# Out:
# (22578, 9)
# (627, 8)
# 627×8 DataFrames.DataFrame. Omitted printing of 3 columns
# │ Row │ Person1 │ Person2 │ Pedigree1 │ Pedigree2 │ Mendel_empiric │
# ├─────┼─────────┼─────────┼───────────┼───────────┼────────────────┤
# │ 1   │ 6790    │ 29      │ 2         │ 2         │ 0.2548         │
# │ 2   │ 6790    │ 2294    │ 2         │ 2         │ 0.24644        │
# │ 3   │ 6790    │ 3416    │ 2         │ 2         │ 0.0            │
# │ 4   │ 14695   │ 6790    │ 2         │ 2         │ 0.26698        │
# │ 5   │ 17893   │ 6790    │ 2         │ 2         │ 0.25369        │
# │ 6   │ 6952    │ 29      │ 2         │ 2         │ 0.1114         │
# │ 7   │ 6952    │ 2294    │ 2         │ 2         │ 0.14461        │
# │ 8   │ 6952    │ 3416    │ 2         │ 2         │ 0.25462        │
# │ 9   │ 6952    │ 3916    │ 2         │ 2         │ 0.10791        │
# │ 10  │ 6952    │ 14695   │ 2         │ 2         │ 0.10753        │
# │ 11  │ 39      │ 39      │ 3         │ 3         │ 0.5            │
# ⋮
# │ 616 │ 19392   │ 4512    │ 31        │ 31        │ 0.0            │
# │ 617 │ 19392   │ 24905   │ 31        │ 31        │ 0.0            │
# │ 618 │ 19392   │ 26007   │ 31        │ 31        │ 0.00184        │
# │ 619 │ 19392   │ 14705   │ 31        │ 31        │ 0.0            │
# │ 620 │ 19392   │ 15802   │ 31        │ 31        │ 0.0            │
# │ 621 │ 19392   │ 15884   │ 31        │ 31        │ 0.0            │
# │ 622 │ 19392   │ 152     │ 31        │ 31        │ 0.0            │
# │ 623 │ 19392   │ 63      │ 31        │ 31        │ 0.0            │
# │ 624 │ 19392   │ 10472   │ 31        │ 31        │ 0.0            │
# │ 625 │ 19392   │ 12608   │ 31        │ 31        │ 0.0            │
# │ 626 │ 19392   │ 21403   │ 31        │ 31        │ 0.0            │
# │ 627 │ 234     │ 234     │ 10040     │ 10040     │ 0.594          │
